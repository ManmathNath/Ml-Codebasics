# %% [markdown]
# <a href="https://colab.research.google.com/github/ManmathNath/Ml-Codebasics/blob/main/5_dummy_variable%20%26one_hot_encoding/DUMMY%20VARIABLE%20excercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("carprices (1).csv")
df
dummies=pd.get_dummies(df["Car Model"])
dummies
newdf=pd.concat([df,dummies],axis=1)
newdf
final=newdf.drop(["Car Model","Mercedez Benz C class"],axis=1)
final
#before we use train_test_split method we need to define x and y
x=final.drop(["Sell Price($)"],axis=1)
y=df["Sell Price($)"]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.01,random_state=10)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
model.predict(x_test)
model.score(x,y)
#price of a bmw×5  7 yr old mileage 86000
model.predict([[86000,7,0,1]])
#price of Mercedez benz 4 yr with 45000 mileage
model.predict([[45000,4,0,0]])
model.score(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 0.939264522791337

# %%
y_test
# Out:
# 3    40000
# Name: Sell Price($), dtype: int64

# %%
final
# Out:
#     Mileage  Sell Price($)  Age(yrs)  Audi A5  BMW X5
# 0     69000          18000         6        0       1
# 1     35000          34000         3        0       1
# 2     57000          26100         5        0       1
# 3     22500          40000         2        0       1
# 4     46000          31500         4        0       1
# 5     59000          29400         5        1       0
# 6     52000          32000         5        1       0
# 7     72000          19300         6        1       0
# 8     91000          12000         8        1       0
# 9     67000          22000         6        0       0
# 10    83000          20000         7        0       0
# 11    79000          21000         7        0       0
# 12    59000          33000         5        0       0
