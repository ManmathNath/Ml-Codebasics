# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df.head()
new_df=df.drop (['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)
new_df.head(5)
inputs=new_df.drop('Survived',axis=1)
inputs
target=new_df.Survived
inputs.Age=inputs.Age.fillna(df.Age.median())
inputs.Sex=inputs.Sex.map({'male':1,'female':2})
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs,target,test_size=0.25,random_state=10)
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
model.score(x_test,y_test)
#model.predict(x_test)
# Out:
# 0.8116591928251121

# %%
#confusion_matrics
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import confusion_matrix
y_predicted = model.predict(x_test)
cm = confusion_matrix(y_test,y_predicted)
cm
#draw confusion_matrix
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm,annot=True)
plt.xlabel('y_predicted ')
plt.ylabel('Truevalue')
# Out:
# Text(95.72222222222221, 0.5, 'Truevalue')

# %%
inputs.head(10)
# Out:
#    Pclass  Sex   Age     Fare
# 0       3    1  22.0   7.2500
# 1       1    2  38.0  71.2833
# 2       3    2  26.0   7.9250
# 3       1    2  35.0  53.1000
# 4       3    1  35.0   8.0500
# 5       3    1  28.0   8.4583
# 6       1    1  54.0  51.8625
# 7       3    1   2.0  21.0750
# 8       3    2  27.0  11.1333
# 9       2    2  14.0  30.0708
